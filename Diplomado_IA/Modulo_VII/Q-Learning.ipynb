# %% [markdown]
# # Ejercicio 1

# %%
import gymnasium as gym
import numpy as np
from random import randint

# %%
env= gym.make("MountainCar-v0")

# %% [markdown]
# [ambiente](https://gymnasium.farama.org/environments/classic_control/mountain_car/)

# %%
def discretizar(valor):
    aux = ((valor - env.observation_space.low)/(env.observation_space.high-env.observation_space.low))*20
    return tuple(aux.astype(np.int32))

# %%
q_table = np.random.uniform(low=-1, high=1, size=[20,20,3])

# %%
print(discretizar(env.reset()[0]))
env.close()
# Out:
# (np.int32(8), np.int32(10))

# %%
alfa = 0.1
gamma = 0.95
episodios = 5000
lista_recompenzas = []
for episodio in range(episodios):
    estado=discretizar(env.reset()[0])
    final= False
    f1 = False
    f2 = False
    recompensa_total = 0
    while not final:
        if randint(0,10)>2:
            accion = np.argmax(q_table[estado])
        else:
            accion =randint(0,2)
            
        nuevo_estado,recompensa,f1,f2,info = env.step(accion)
        q_table[estado][accion] = q_table[estado][accion] + alfa*(recompensa+gamma*np.max(q_table[discretizar(nuevo_estado)])-q_table[estado][accion])
        estado= discretizar(nuevo_estado)
        recompensa_total+=recompensa
        final= f1 or f2
    lista_recompenzas.append(recompensa_total)
    if (episodio+1)%100==0:
        print("Episodio: "+str(episodio)+"| Recompensa promedio: "+str(np.mean(lista_recompenzas)))

env.close()
# Out:
# Episodio: 99| Recompensa promedio: -200.0
# Episodio: 199| Recompensa promedio: -200.0
# Episodio: 299| Recompensa promedio: -200.0
# Episodio: 399| Recompensa promedio: -200.0
# Episodio: 499| Recompensa promedio: -200.0
# Episodio: 599| Recompensa promedio: -200.0
# Episodio: 699| Recompensa promedio: -199.96142857142857
# Episodio: 799| Recompensa promedio: -199.89125
# Episodio: 899| Recompensa promedio: -199.73666666666668
# Episodio: 999| Recompensa promedio: -199.739
# Episodio: 1099| Recompensa promedio: -199.6690909090909
# Episodio: 1199| Recompensa promedio: -199.68083333333334
# Episodio: 1299| Recompensa promedio: -199.50307692307692
# Episodio: 1399| Recompensa promedio: -199.48357142857142
# Episodio: 1499| Recompensa promedio: -199.05866666666665
# Episodio: 1599| Recompensa promedio: -199.088125
# Episodio: 1699| Recompensa promedio: -198.87470588235294
# Episodio: 1799| Recompensa promedio: -198.745
# Episodio: 1899| Recompensa promedio: -198.50052631578947
# Episodio: 1999| Recompensa promedio: -198.461
# Episodio: 2099| Recompensa promedio: -198.3709523809524
# Episodio: 2199| Recompensa promedio: -198.20545454545456
# Episodio: 2299| Recompensa promedio: -198.07478260869564
# Episodio: 2399| Recompensa promedio: -197.60458333333332
# Episodio: 2499| Recompensa promedio: -197.62
# Episodio: 2599| Recompensa promedio: -197.56884615384615
# Episodio: 2699| Recompensa promedio: -197.32444444444445
# Episodio: 2799| Recompensa promedio: -197.35285714285715
# Episodio: 2899| Recompensa promedio: -197.3303448275862
# Episodio: 2999| Recompensa promedio: -197.417
# Episodio: 3099| Recompensa promedio: -197.42451612903227
# Episodio: 3199| Recompensa promedio: -197.414375
# Episodio: 3299| Recompensa promedio: -197.31242424242424
# Episodio: 3399| Recompensa promedio: -197.3394117647059
# Episodio: 3499| Recompensa promedio: -197.254
# Episodio: 3599| Recompensa promedio: -197.1822222222222
# Episodio: 3699| Recompensa promedio: -197.10675675675677
# Episodio: 3799| Recompensa promedio: -197.0286842105263
# Episodio: 3899| Recompensa promedio: -197.08
# Episodio: 3999| Recompensa promedio: -197.0645
# Episodio: 4099| Recompensa promedio: -196.8690243902439
# Episodio: 4199| Recompensa promedio: -196.74642857142857
# Episodio: 4299| Recompensa promedio: -196.52279069767442
# Episodio: 4399| Recompensa promedio: -196.39068181818183
# Episodio: 4499| Recompensa promedio: -196.25555555555556
# Episodio: 4599| Recompensa promedio: -196.18891304347827
# Episodio: 4699| Recompensa promedio: -196.198085106383
# Episodio: 4799| Recompensa promedio: -196.11895833333332
# Episodio: 4899| Recompensa promedio: -195.89489795918368
# Episodio: 4999| Recompensa promedio: -195.8504

# %%
env= gym.make("MountainCar-v0", render_mode="human")

# %%
estado=discretizar(env.reset()[0])
final= False
f1 = False
f2 = False
recompensa_total = 0
while not final:
    
    accion = np.argmax(q_table[estado])
      
    nuevo_estado,recompensa,f1,f2,info = env.step(accion)
    estado= discretizar(nuevo_estado)
  
    final= f1 or f2
env.close()

# %% [markdown]
# ## Fuentes
#
# [Q-Learning](https://www.youtube.com/watch?v=Vyty4dbag4w)
