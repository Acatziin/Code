# %%
# ============================================================
# CUESTIONARIO:
# RNNs, LSTM, GRU Y RNNs CON ATENCIÓN
# ============================================================
#
# INSTRUCCIONES:
#
# 1. Responde cada pregunta en texto o código según se indique.
# 2. Algunas preguntas son conceptuales.
# 3. Algunas preguntas requieren explicación matemática.
# 4. Algunas preguntas requieren modificar código.
# 5. Justifica tus respuestas.
#
# Temas evaluados:
# - Redes de Elman
# - Redes de Jordan
# - Problema del gradiente desvaneciente
# - LSTM
# - GRU
# - Softmax
# - Atención
# - Seq2Seq
# - RNNs con atención
# - Entregar el miercoles 13 de mayo
# ============================================================

# %%
# ============================================================
# PREGUNTA 1
# ============================================================
#
# Explica con tus propias palabras:
#
# ¿Qué diferencia existe entre una red neuronal tradicional
# feedforward y una RNN?
#
# Menciona:
# - memoria
# - dependencia temporal
# - procesamiento secuencial
#
# RESPUESTA:
#

# ============================================================
# PREGUNTA 2
# ============================================================
#
# Explica la diferencia entre:
#
# a) Red de Elman
# b) Red de Jordan
#
# ¿Qué se retroalimenta en cada una?
#
# RESPUESTA:
#

# ============================================================
# PREGUNTA 3
# ============================================================
#
# ¿Por qué una RNN simple puede olvidar información lejana?
#
# Explica:
# - gradiente desvaneciente
# - multiplicaciones sucesivas
# - saturación de tanh o sigmoid
#
# RESPUESTA:
#

# ============================================================
# PREGUNTA 4
# ============================================================
#
# Explica qué problema intenta resolver LSTM.
#
# ¿Por qué las compuertas ayudan?
#
# RESPUESTA:
#

# ============================================================
# PREGUNTA 5
# ============================================================
#
# Explica la función de:
#
# a) Forget Gate
# b) Input Gate
# c) Output Gate
#
# RESPUESTA:
#

# ============================================================
# PREGUNTA 6
# ============================================================
#
# Explica por qué ReLU normalmente NO se usa
# como activación principal dentro de una LSTM clásica.
#
# RESPUESTA:
#

# ============================================================
# PREGUNTA 7
# ============================================================
#
# Explica:
#
# ¿Qué diferencia principal existe entre LSTM y GRU?
#
# RESPUESTA:
#

# ============================================================
# PREGUNTA 8
# ============================================================
#
# ¿Por qué GRU suele entrenar más rápido que LSTM?
#
# RESPUESTA:
#

# ============================================================
# PREGUNTA 9
# ============================================================
#
# Explica el problema del "cuello de botella"
# en modelos Seq2Seq sin atención.
#
# RESPUESTA:
#

# ============================================================
# PREGUNTA 10
# ============================================================
#
# En atención:
#
# ¿Qué representa cada uno?
#
# a) Query
# b) Key
# c) Value
#
# RESPUESTA:
#
